# %% [markdown]
# <a href="https://colab.research.google.com/github/JustMatthew989/Matvey_Mokritskikh_Repo/blob/main/%D0%94%D0%97_1_%D0%9C%D0%BE%D0%BA%D1%80%D0%B8%D1%86%D0%BA%D0%B8%D1%85_%D0%97%D0%B0%D0%B4%D0%B0%D0%BD%D0%B8%D1%8F_1_%D0%B8_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ЗАДАНИЕ №1.

# !pip install ucimlrepo
import pandas as pd

# %%
from ucimlrepo import fetch_ucirepo

# Получаем датасет
student_performance = fetch_ucirepo(id=320)

# %%
# Данные (как датафреймы Pandas)
X = student_performance.data.features
y = student_performance.data.targets

# %%
# Метаданные
print(student_performance.metadata)

# Инфа о переменной
print(student_performance.variables)
# Out:
# {'uci_id': 320, 'name': 'Student Performance', 'repository_url': 'https://archive.ics.uci.edu/dataset/320/student+performance', 'data_url': 'https://archive.ics.uci.edu/static/public/320/data.csv', 'abstract': 'Predict student performance in secondary education (high school). ', 'area': 'Social Science', 'tasks': ['Classification', 'Regression'], 'characteristics': ['Multivariate'], 'num_instances': 649, 'num_features': 30, 'feature_types': ['Integer'], 'demographics': ['Sex', 'Age', 'Other', 'Education Level', 'Occupation'], 'target_col': ['G1', 'G2', 'G3'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 2008, 'last_updated': 'Fri Jan 05 2024', 'dataset_doi': '10.24432/C5TG7T', 'creators': ['Paulo Cortez'], 'intro_paper': {'ID': 360, 'type': 'NATIVE', 'title': 'Using data mining to predict secondary school student performance', 'authors': 'P. Cortez, A. M. G. Silva', 'venue': 'Proceedings of 5th Annual Future Business Techno
# ...

# %%
student_performance.data.targets
# Out:
#      G1  G2  G3
# 0     0  11  11
# 1     9  11  11
# 2    12  13  12
# 3    14  14  14
# 4    11  13  13
# ..   ..  ..  ..
# 644  10  11  10
# 645  15  15  16
# 646  11  12   9
# 647  10  10  10
# 648  10  11  11
#
# [649 rows x 3 columns]

# %% [markdown]
# А) Ссылка на источник данных, откуда взят датасет: https://archive.ics.uci.edu/dataset/320/student+performance.
#
# Б) Описание датасета:
# Список признаков (столбцов) с их описанием и типами данных:
# 1. school:
# Описание: Название школы, в которой учится студент.
# Тип данных: Категориальный (например, "GP" Gabriel Pereira, "MS" Moussaing).
# 2. sex:
# Описание: Пол студента.
# Тип данных: Категориальный  (например, "F" женский, "M" мужской).
# 3. age:
# Описание: Возраст студента.
# Тип данных: Числовой .
# 4. address:
# Описание: Тип адреса студента (городская или загородная местность).
# Тип данных: Категориальный  (например, "U" городской, "R" сельский).
# 5. famsize:
# Описание: Размер семьи.
# Тип данных: Категориальный  (например, "LE3" меньше или равно 3, "GT3" больше 3).
# 6. Pstatus:
# Описание: Статус совместного проживания с родителями (совместное или раздельное).
# Тип данных: Категориальный  (например, "T" живет с обоими родителями, "A" живет не с обоими).
# 7. medu:
# Описание: Образование матери (в классе от 0 до 4, где 0 без образования, 4 высшее образование).
# Тип данных: Числовой.
# 8. fedu:
# Описание: Образование отца (аналогично образованию матери).
# Тип данных: Числовой.
# 9. mjob:
# Описание: Профессия матери.
# Тип данных: Категориальный.
# 10. fjob:
#  Описание: Профессия отца.
#  Тип данных: Категориальный.
# 11. reason:
#  Описание: Причина выбора этой школы.
#  Тип данных: Категориальный.
# 12. guardian:
#  Описание: Опекун студента.
# Тип данных: Категориальный.
# 13. traveltime:
# Описание: Время в пути до школы (в классах от 1 до 4, где 1 менее 15 минут, 4 более 60 минут).
# Тип данных: Числовой.
# 14. studytime:
# Описание: Время, затрачиваемое на учебу (в классах от 1 до 4).
# Тип данных: Числовой.
# 15. failures:
# Описание: Количество неудач (число несданных предметов).
# Тип данных: Числовой.
# 16. school_sup:
# Описание: Получение образовательной поддержки.
# Тип данных: Категориальный.
# 17. famsup:
# Описание: Наличие поддержки семьи.
# Тип данных: Категориальный.
# 18. paid:
# Описание: Дополнительные платные курсы.
# Тип данных: Категориальный.
# 19. activities:
# Описание: Участие во внеучебной деятельности.
# Тип данных: Категориальный.
# 20. nursery:
# Описание: Посещение детского сада.
# Тип данных: Категориальный.
# 21. higher:
# Описание: Стремление к высшему образованию.
# Тип данных: Категориальный.
# 22. internet:
# Описание: Доступ к интернету.
# Тип данных: Категориальный.
# 23. romantic:
# Описание: Наличие романтических отношений.
# Тип данных: Категориальный.
# 24. famrel:
# Описание: Оценка отношений в семье (по шкале от 1 до 5).
# Тип данных: Числовой.
# 25. freetime:
# Описание: Уровень свободного времени (по шкале от 1 до 5).
# Тип данных: Числовой.
# 26. goout:
# Описание: Социальная активность (по шкале от 1 до 5).
# Тип данных: Числовой.
# 27. Dalc:
# Описание: Потребление алкоголя по дням в неделю (по шкале от 1 до 5).
# Тип данных: Числовой.
# 28. Walc:
# Описание: Потребление алкоголя в выходные дни (по шкале от 1 до 5).
# Тип данных: Числовой.
# 29. health:
# Описание: Оценка состояния здоровья (по шкале от 1 до 5).
# Тип данных: Числовой.
# 30. absences:
# Описание: Количество пропусков (в днях).
# Тип данных: Числовой.
# 31. G1:
# Описание: Оценка в первом семестре (от 0 до 20).
# Тип данных: Числовой.
# 32. G2:
# Описание: Оценка во втором семестре (от 0 до 20).
# Тип данных: Числовой.
# 33. G3:
# Описание: Окончательная оценка (от 0 до 20).
# Тип данных: Числовой.
#
# В) Целевая переменная: G3.
# Описание: Окончательная оценка студента в конце учебного года, может использоваться для анализа факторов, влияющих на успеваемость студентов.
# Тип данных: Числовой.

# %%
# ЗАДАНИЕ №2.

# !pip install ucimlrepo
import pandas as pd

# %%
from ucimlrepo import fetch_ucirepo

# Получаем датасет
iris = fetch_ucirepo(id=53)

# Данные (как датафреймы Pandas)
X = iris.data.features
y = iris.data.targets

# Метаданные
print(iris.metadata)

# Инфа о переменной
print(iris.variables)
# Out:
# {'uci_id': 53, 'name': 'Iris', 'repository_url': 'https://archive.ics.uci.edu/dataset/53/iris', 'data_url': 'https://archive.ics.uci.edu/static/public/53/data.csv', 'abstract': 'A small classic dataset from Fisher, 1936. One of the earliest known datasets used for evaluating classification methods.\n', 'area': 'Biology', 'tasks': ['Classification'], 'characteristics': ['Tabular'], 'num_instances': 150, 'num_features': 4, 'feature_types': ['Real'], 'demographics': [], 'target_col': ['class'], 'index_col': None, 'has_missing_values': 'no', 'missing_values_symbol': None, 'year_of_dataset_creation': 1936, 'last_updated': 'Tue Sep 12 2023', 'dataset_doi': '10.24432/C56C76', 'creators': ['R. A. Fisher'], 'intro_paper': {'ID': 191, 'type': 'NATIVE', 'title': 'The Iris data set: In search of the source of virginica', 'authors': 'A. Unwin, K. Kleinman', 'venue': 'Significance, 2021', 'year': 2021, 'journal': 'Significance, 2021', 'DOI': '1740-9713.01589', 'URL': 'https://www.semanticscholar.o
# ...

# %%
iris.data.targets
# Out:
#               class
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica
#
# [150 rows x 1 columns]

# %% [markdown]
# А) Ссылка на источник данных, откуда взят датасет: https://archive.ics.uci.edu/dataset/53/iris .
#
# Б) Описание данных:
# Список признаков (столбцов) с их описанием и типами данных:
# 1. sepal length (cm):
# Описание: Длина чашелистика в сантиметрах.
# Тип данных: Числовой.
# 2. sepal width (cm):
# Описание: Ширина чашелистика в сантиметрах.
# Тип данных: Числовой.
# 3. petal length (cm):
# Описание: Длина лепестка в сантиметрах.
# Тип данных: Числовой.
# 4. petal width (cm):
# Описание: Ширина лепестка в сантиметрах.
# Тип данных: Числовой.
# 5. class:
# Описание: Класс ириса, к которому принадлежит взятый экземпляр.
# Тип данных: Категориальный (три возможных класса: "Iris-setosa", "Iris-versicolor", "Iris-virginica”).
#
# В) Целевая переменная: class.
# Описание: Название класса, к которому относится данный экземпляр ириса. Это целевая переменная, по которой будут производиться классификация и анализ. Каждый экземпляр в датасете принадлежит к одному из трех видов ирисов: Iris-setosa, Iris-versicolor или Iris-virginica.
# Тип данных: Категориальный.
